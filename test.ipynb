# %%
import sys, os

fromdir = "/media/roni/New Volume/CODDING/PROJECTS/ionia-next/frontend"

def print_structure(path, indent=""):
    """Recursively prints the file structure, skipping .git, .next, and node_modules."""
    for root, dirs, files in os.walk(path):
        # Skip .git, .next, and node_modules directories
        dirs[:] = [d for d in dirs if d not in ('.git', '.next', 'node_modules')]

        # Get relative path from the root directory
        rel_root = os.path.relpath(root, fromdir)
        if rel_root == ".":
            rel_root = ""  # Ensure root directory is printed without extra "/"
        
        # Print the current directory if it's not the base directory
        if rel_root:
            print(f"{indent}{rel_root}/")
            indent += "    "  # Add indentation for subdirectories
        
        # Print files inside the current directory
        for file in files:
            file_path = os.path.join(root, file)
            rel_file = os.path.relpath(file_path, fromdir)
            print(f"{indent}├── {rel_file}")

# Start from the given directory

# %%
print_structure(fromdir)
# Out:
# ├── .env
# ├── .gitignore
# ├── .prettierrc
# ├── eslint.config.mjs
# ├── next-env.d.ts
# ├── next.config.ts
# ├── package-lock.json
# ├── package.json
# ├── postcss.config.js
# ├── postcss.config.mjs
# ├── README.md
# ├── tailwind.config.js
# ├── tailwind.config.ts
# ├── tsconfig.json
# public/
#     ├── public/file.svg
#     ├── public/globe.svg
#     ├── public/next.svg
#     ├── public/vercel.svg
#     ├── public/window.svg
#     src/
#         src/app/
#             ├── src/app/layout.tsx
#             ├── src/app/page.tsx
#             ├── src/app/_app.tsx
#             src/app/admin/
#                 ├── src/app/admin/layout.tsx
#                 ├── src/app/admin/page.tsx
#                 src/app/admin/questions/
#                     ├── src/app/admin/questions/page.tsx
#                     src/app/admin/questions/add/
#                         ├── src/app/admin/questions/add/page.tsx
#                         src/app/admin/tests/
#                             ├── src/app/admin/tests/page.tsx
#                             src/app/admin/tests/create/
#                                 ├── src/app/admin/tests/create/page.tsx
#                                 src/app/admin/tests/view/
#                                     src/app/admin/tests/view/[id]/
#                                         ├── src/app/admin/tests/view/[id]/page.tsx
#                                         src/app/admin/utils/
#                                             ├── src/app/admin/utils/api.ts
#                                             src/app/auth/
#                                                 src/app/auth/forgot-password/
#                                                     ├── src/app/auth/forgot-password/page.tsx
#                                                     src/app/auth/login/
#                                                         ├── src/app/auth/login/layout.tsx
#                                                         ├── src/app/auth/login/loading.tsx
#                                                         ├── src/app/auth/login/page.tsx
#                                                         src/app/auth/register/
#                                                             ├── src/app/auth/register/loading.tsx
#                                                             ├── src/app/auth/register/page.tsx
#                                                             src/app/custom-test/
#                                                                 ├── src/app/custom-test/page.tsx
#                                                                 src/app/custom-test/create/
#                                                                     ├── src/app/custom-test/create/page.tsx
#                                                                     src/app/custom-test/[testId]/
#                                                                         ├── src/app/custom-test/[testId]/page.tsx
#                                                                         src/app/dashboard/
#                                                                             ├── src/app/dashboard/layout.tsx
#                                                                             ├── src/app/dashboard/loading.tsx
#                                                                             ├── src/app/dashboard/page.tsx
#                                                                             src/app/exam/
#                                                                                 src/app/exam/[examType]/
#                                                                                     ├── src/app/exam/[examType]/page.tsx
#                                                                                     src/app/exam/[examType]/practice/
#                                                                                         ├── src/app/exam/[examType]/practice/page.tsx
#                                                                                         src/app/exam/[examType]/previous-year-paper/
#                                                                                             ├── src/app/exam/[examType]/previous-year-paper/page.tsx
#                                                                                             src/app/exam/[examType]/previous-year-paper/[paperId]/
#                                                                                                 ├── src/app/exam/[examType]/previous-year-paper/[paperId]/page.tsx
#                                                                                                 src/app/exam/[examType]/previous-year-paper/[paperId]/instructions/
#                                                                                                     ├── src/app/exam/[examType]/previous-year-paper/[paperId]/instructions/page.tsx
#                                                                                                     src/app/exam/[examType]/previous-year-paper/[paperId]/test/
#                                                                                                         ├── src/app/exam/[examType]/previous-year-paper/[paperId]/test/layout.tsx
#                                                                                                         ├── src/app/exam/[examType]/previous-year-paper/[paperId]/test/page.jsx
#                                                                                                         src/app/exam/[examType]/[subject]/
#                                                                                                             ├── src/app/exam/[examType]/[subject]/page.tsx
#                                                                                                             src/app/exam/[examType]/[subject]/[testId]/
#                                                                                                                 ├── src/app/exam/[examType]/[subject]/[testId]/page.tsx
#                                                                                                                 src/app/exam/[examType]/[subject]/[testId]/results/
#                                                                                                                     ├── src/app/exam/[examType]/[subject]/[testId]/results/page.tsx
#                                                                                                                     src/app/practices/
#                                                                                                                         ├── src/app/practices/page.tsx
#                                                                                                                         src/app/practices/[subjectId]/
#                                                                                                                             ├── src/app/practices/[subjectId]/page.tsx
#                                                                                                                             src/app/practices/[subjectId]/[chapterId]/
#                                                                                                                                 ├── src/app/practices/[subjectId]/[chapterId]/page.tsx
#                                                                                                                                 src/app/profile/
#                                                                                                                                     ├── src/app/profile/page.tsx
#                                                                                                                                     src/app/profile/settings/
#                                                                                                                                         ├── src/app/profile/settings/page.tsx
#                                                                                                                                         src/components/
#                                                                                                                                             src/components/auth/
#                                                                                                                                                 ├── src/components/auth/ForgotPasswordForm.tsx
#                                                                                                                                                 ├── src/components/auth/LoginForm.tsx
#                                                                                                                                                 ├── src/components/auth/RegisterForm.tsx
#                                                                                                                                                 src/components/common/
#                                                                                                                                                     ├── src/components/common/Button.tsx
#                                                                                                                                                     ├── src/components/common/Footer.tsx
#                                                                                                                                                     ├── src/components/common/Input.tsx
#                                                                                                                                                     ├── src/components/common/Layout.tsx
#                                                                                                                                                     ├── src/components/common/Loading.tsx
#                                                                                                                                                     ├── src/components/common/Modal.tsx
#                                                                                                                                                     ├── src/components/common/Navbar.tsx
#                                                                                                                                                     ├── src/components/common/Select.tsx
#                                                                                                                                                     src/components/dashboard/
#                                                                                                                                                         ├── src/components/dashboard/card.tsx
#                                                                                                                                                         ├── src/components/dashboard/PerformanceChart.tsx
#                                                                                                                                                         ├── src/components/dashboard/RecentTests.tsx
#                                                                                                                                                         ├── src/components/dashboard/Sidebar.tsx
#                                                                                                                                                         ├── src/components/dashboard/StatsCard.tsx
#                                                                                                                                                         ├── src/components/dashboard/UpcomingTests.tsx
#                                                                                                                                                         src/components/practice/
#                                                                                                                                                             ├── src/components/practice/AnswerSummary.tsx
#                                                                                                                                                             ├── src/components/practice/ChapterList.tsx
#                                                                                                                                                             ├── src/components/practice/PracticeQuestion.tsx
#                                                                                                                                                             ├── src/components/practice/ResultPage.tsx
#                                                                                                                                                             ├── src/components/practice/TopicCard.tsx
#                                                                                                                                                             src/components/test/
#                                                                                                                                                                 ├── src/components/test/hey
#                                                                                                                                                                 src/components/test/TestWindow/
#                                                                                                                                                                     ├── src/components/test/TestWindow/index.tsx
#                                                                                                                                                                     ├── src/components/test/TestWindow/QuestionPanel.tsx
#                                                                                                                                                                     src/components/test/TestWindow/Controls/
#                                                                                                                                                                         ├── src/components/test/TestWindow/Controls/ActionButtons.tsx
#                                                                                                                                                                         ├── src/components/test/TestWindow/Controls/LanguageSelector.tsx
#                                                                                                                                                                         src/components/test/TestWindow/Header/
#                                                                                                                                                                             ├── src/components/test/TestWindow/Header/CandidateInfo.tsx
#                                                                                                                                                                             ├── src/components/test/TestWindow/Header/Timer.tsx
#                                                                                                                                                                             src/components/test/TestWindow/Navigation/
#                                                                                                                                                                                 ├── src/components/test/TestWindow/Navigation/NavigationButtons.tsx
#                                                                                                                                                                                 ├── src/components/test/TestWindow/Navigation/QuestionGrid.tsx
#                                                                                                                                                                                 src/components/test/TestWindow/StatusPanel/
#                                                                                                                                                                                     ├── src/components/test/TestWindow/StatusPanel/Legend.tsx
#                                                                                                                                                                                     ├── src/components/test/TestWindow/StatusPanel/QuestionStatus.tsx
#                                                                                                                                                                                     src/components/test/TestWindow/styles/
#                                                                                                                                                                                         ├── src/components/test/TestWindow/styles/TestWindow.module.css
#                                                                                                                                                                                         src/context/
#                                                                                                                                                                                             ├── src/context/AuthContext.tsx
#                                                                                                                                                                                             src/lib/
#                                                                                                                                                                                                 src/lib/api/
#                                                                                                                                                                                                     ├── src/lib/api/auth.ts
#                                                                                                                                                                                                     ├── src/lib/api/questions.ts
#                                                                                                                                                                                                     ├── src/lib/api/tests.ts
#                                                                                                                                                                                                     ├── src/lib/api/user.ts
#                                                                                                                                                                                                     src/lib/hooks/
#                                                                                                                                                                                                         ├── src/lib/hooks/useAuth.ts
#                                                                                                                                                                                                         ├── src/lib/hooks/useQuestionNavigation.ts
#                                                                                                                                                                                                         ├── src/lib/hooks/useQuestionStatus.ts
#                                                                                                                                                                                                         ├── src/lib/hooks/useTestProgress.ts
#                                                                                                                                                                                                         ├── src/lib/hooks/useTestSession.ts
#                                                                                                                                                                                                         ├── src/lib/hooks/useTimer.ts
#                                                                                                                                                                                                         src/lib/utils/
#                                                                                                                                                                                                             ├── src/lib/utils/format.ts
#                                                                                                                                                                                                             ├── src/lib/utils/time.ts
#                                                                                                                                                                                                             ├── src/lib/utils/validation.ts
#                                                                                                                                                                                                             src/styles/
#                                                                                                                                                                                                                 ├── src/styles/globals.css
#                                                                                                                                                                                                                 src/types/
#                                                                                                                                                                                                                     ├── src/types/global.d.ts
#                                                                                                                                                                                                                     ├── src/types/question.ts
#                                                                                                                                                                                                                     ├── src/types/test.ts
#                                                                                                                                                                                                                     ├── src/types/testWindow.ts
#                                                                                                                                                                                                                     ├── src/types/user.ts
